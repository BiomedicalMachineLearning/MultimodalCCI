# %%
"""
Squidpy implementation of CPDB on simulated data.

            INPUT: * data/sim_data/spatialsim_v2.h5ad
            OUTPUT: * data/sim_data/methods_out/squidpy_ints.txt
"""

################################################################################
                         # Environment setup #
################################################################################
# TODO update work_dir
work_dir = '/home/uqlhocke/Aging/Levi/Scripts/LR_CCI/benchmarking/'
data_dir = '/scratch/project/stseq/Levi/mmcci_benchmarking/'
out_dir = data_dir

import os
os.chdir(work_dir)

import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq
import pickle

################################################################################
                        # Loading the data #
################################################################################
data = sc.read_h5ad(data_dir+'sample1.h5ad')

################################################################################
                        # Running squidpy #
################################################################################
result = sq.gr.ligrec(data, n_perms=10000, cluster_key="cell_type",
                      copy=True, use_raw=False,
                      show_progress_bar = True,
                      corr_method='fdr_bh', corr_axis='clusters',
                      threshold=0
                    )
pvals = pd.DataFrame(result['pvalues'])

################################################################################
     # Creating a CCI interaction matrix equivalent to other methods #
################################################################################
cci_names = np.array([col[0]+'--'+col[1] for col in pvals.columns])
cell_type_set = np.unique([col[0] for col in pvals.columns])

lr_dict = {}

for i, row in enumerate(pvals.index):
    
    int_matrix = np.zeros((len(cell_type_set), len(cell_type_set)))
    lr_ = '_'.join(list(row))

    # Getting sig CCIs for this lr #
    lr_pvals = np.array(pvals.values[i,:])
    sig_bool = lr_pvals < .05
    lr_ccis = cci_names[sig_bool]
    lig = list(row)[0]
    rec = list(row)[1]
    for j, cci in enumerate(lr_ccis):
        c1, c2 = cci.split('--')
        row = np.where(cell_type_set==c1)[0][0]
        col = np.where(cell_type_set==c2)[0][0]
        int_matrix[row,col] = result['means'][c1][c2][lig][rec]

    lr_dict[lr_] = pd.DataFrame(int_matrix, index=cell_type_set, columns=cell_type_set)

with open(data_dir+'squidpy_sample1.pkl', 'wb') as f:
    pickle.dump(lr_dict, f)
# Out:
# /home/uqlhocke/micromamba/envs/py-env/lib/python3.9/site-packages/squidpy/gr/_ligrec.py:732: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = data.groupby("clusters")
#   0%|          | 0/10000 [00:00<?, ?permutation/s]

# %%
################################################################################
                        # Loading the data #
################################################################################
data = sc.read_h5ad(data_dir+'sample2.h5ad')

################################################################################
                        # Running squidpy #
################################################################################
result = sq.gr.ligrec(data, n_perms=10000, cluster_key="cell_type",
                      copy=True, use_raw=False,
                      show_progress_bar = True,
                      corr_method='fdr_bh', corr_axis='clusters',
                      threshold=0
                    )
pvals = pd.DataFrame(result['pvalues'])

################################################################################
     # Creating a CCI interaction matrix equivalent to other methods #
################################################################################
cci_names = np.array([col[0]+'--'+col[1] for col in pvals.columns])
cell_type_set = np.unique([col[0] for col in pvals.columns])

lr_dict = {}

for i, row in enumerate(pvals.index):
    
    int_matrix = np.zeros((len(cell_type_set), len(cell_type_set)))
    lr_ = '_'.join(list(row))

    # Getting sig CCIs for this lr #
    lr_pvals = np.array(pvals.values[i,:])
    sig_bool = lr_pvals < .05
    lr_ccis = cci_names[sig_bool]
    lig = list(row)[0]
    rec = list(row)[1]
    for j, cci in enumerate(lr_ccis):
        c1, c2 = cci.split('--')
        row = np.where(cell_type_set==c1)[0][0]
        col = np.where(cell_type_set==c2)[0][0]
        int_matrix[row,col] = result['means'][c1][c2][lig][rec]

    lr_dict[lr_] = pd.DataFrame(int_matrix, index=cell_type_set, columns=cell_type_set)

with open(data_dir+'squidpy_sample2.pkl', 'wb') as f:
    pickle.dump(lr_dict, f)
# Out:
# /home/uqlhocke/micromamba/envs/py-env/lib/python3.9/site-packages/squidpy/gr/_ligrec.py:732: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = data.groupby("clusters")
#   0%|          | 0/10000 [00:00<?, ?permutation/s]

# %%
################################################################################
                        # Loading the data #
################################################################################
data = sc.read_h5ad(data_dir+'sample3.h5ad')

# ################################################################################
#                         # Running squidpy #
# ################################################################################
result = sq.gr.ligrec(data, n_perms=10000, cluster_key="cell_type",
                      copy=True, use_raw=False,
                      show_progress_bar = True,
                      corr_method='fdr_bh', corr_axis='clusters',
                      threshold=0
                    )
pvals = pd.DataFrame(result['pvalues'])

################################################################################
     # Creating a CCI interaction matrix equivalent to other methods #
################################################################################
cci_names = np.array([col[0]+'--'+col[1] for col in pvals.columns])
cell_type_set = np.unique([col[0] for col in pvals.columns])

lr_dict = {}

for i, row in enumerate(pvals.index):
    
    int_matrix = np.zeros((len(cell_type_set), len(cell_type_set)))
    lr_ = '_'.join(list(row))

    # Getting sig CCIs for this lr #
    lr_pvals = np.array(pvals.values[i,:])
    sig_bool = lr_pvals < .05
    lr_ccis = cci_names[sig_bool]
    lig = list(row)[0]
    rec = list(row)[1]
    for j, cci in enumerate(lr_ccis):
        c1, c2 = cci.split('--')
        row = np.where(cell_type_set==c1)[0][0]
        col = np.where(cell_type_set==c2)[0][0]
        int_matrix[row,col] = result['means'][c1][c2][lig][rec]

    lr_dict[lr_] = pd.DataFrame(int_matrix, index=cell_type_set, columns=cell_type_set)

with open(data_dir+'squidpy_sample3.pkl', 'wb') as f:
    pickle.dump(lr_dict, f)
# Out:
# /home/uqlhocke/micromamba/envs/py-env/lib/python3.9/site-packages/squidpy/gr/_ligrec.py:732: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = data.groupby("clusters")
#   0%|          | 0/10000 [00:00<?, ?permutation/s]

# %%
pvals
# Out:
# cluster_1     Bcell                                     Tcell        \
# cluster_2     Bcell Tcell luminal_ar mesenchymal stroma Bcell Tcell
# source target
# EPOR   TRPC3    NaN   NaN        NaN    0.000000    NaN   NaN   NaN
#        JAK2     1.0   1.0        0.0    0.614323    0.0   1.0   1.0
# FYN    JAK2     1.0   1.0        1.0    1.000000    1.0   0.0   0.0
# CCL2   JAK2     NaN   NaN        NaN         NaN    NaN   1.0   1.0
# KIT    JAK2     NaN   NaN        NaN         NaN    NaN   1.0   1.0
# ...             ...   ...        ...         ...    ...   ...   ...
# SLC1A1 GRIN2D   NaN   NaN        NaN         NaN    NaN   NaN   NaN
# SLC1A3 GRIN2D   NaN   NaN        NaN         NaN    NaN   NaN   NaN
# SLC1A7 GRIN2D   NaN   NaN        NaN         NaN    NaN   NaN   NaN
# GLS2   GRIN2D   NaN   NaN        NaN         NaN    NaN   NaN   NaN
# TYMP   HPGDS    NaN   NaN        NaN         NaN    0.0   NaN   NaN
#
# cluster_1                                       ... mesenchymal            \
# cluster_2     luminal_ar mesenchymal    stroma  ...       Bcell     Tcell
# source target                                   ...
# EPOR   TRPC3         NaN         1.0       NaN  ...         NaN       NaN
#        JAK2     0.000000         1.0  1.000000  ...         0.0  0.202703
# FYN    JAK2     0.000000         0.0  0.000000  ...         1.0  1.000000
# CCL2   JAK2     0.080639         1.0  1.000000  ...         1.0  1.000000
# KIT    JAK2     0.059964         1.0  1.000000  ...         0.0  0.000000
# ...                  ...         ...       ...  ...         ...       ...
# SLC1A1 GRIN2D        NaN         NaN       NaN  ...         NaN       NaN
# SLC1A3 GRIN2D        NaN         1.0       NaN  ...         NaN       NaN
# SLC1A7 GRIN2D        NaN         NaN       NaN  ...         NaN       NaN
# GLS2   GRIN2D        NaN         NaN       NaN  ...         NaN       NaN
# TYMP   HPGDS         NaN         NaN  0.827408  ...         NaN       NaN
#
# cluster_1                                   stroma                   \
# cluster_2     luminal_ar mesenchymal stroma  Bcell Tcell luminal_ar
# source target
# EPOR   TRPC3         NaN    0.000000    NaN    NaN   NaN        NaN
#        JAK2          0.0    0.000000    0.0    1.0   1.0        0.0
# FYN    JAK2          0.0    1.000000    0.0    1.0   1.0        0.0
# CCL2   JAK2          0.0    0.006258    0.0    0.0   0.0        0.0
# KIT    JAK2          0.0    0.000000    0.0    1.0   1.0        0.0
# ...                  ...         ...    ...    ...   ...        ...
# SLC1A1 GRIN2D        NaN    1.000000    NaN    NaN   NaN        NaN
# SLC1A3 GRIN2D        NaN    0.000000    NaN    NaN   NaN        NaN
# SLC1A7 GRIN2D        NaN         NaN    NaN    NaN   NaN        NaN
# GLS2   GRIN2D        NaN    0.000000    NaN    NaN   NaN        NaN
# TYMP   HPGDS         NaN         NaN    1.0    NaN   NaN        NaN
#
# cluster_1
# cluster_2     mesenchymal stroma
# source target
# EPOR   TRPC3          1.0    NaN
#        JAK2           1.0    1.0
# FYN    JAK2           1.0    0.0
# CCL2   JAK2           0.0    0.0
# KIT    JAK2           1.0    1.0
# ...                   ...    ...
# SLC1A1 GRIN2D         1.0    NaN
# SLC1A3 GRIN2D         0.0    NaN
# SLC1A7 GRIN2D         0.0    NaN
# GLS2   GRIN2D         1.0    NaN
# TYMP   HPGDS          NaN    1.0
#
# [5521 rows x 25 columns]
